# %% [markdown]
# # Задание 1

# %%
import numpy as np
import pandas as pd

from keras.models import Sequential
from keras.layers.core import Dense
from keras.utils import np_utils
from keras import optimizers

# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'svg' 

from pylab import rcParams
rcParams['figure.figsize'] = 8, 5

# %%
df_train = pd.read_csv("nums_train.csv")
X_train, Y_train = df_train.values[:, 1:], df_train.values[:, 0]

df_test = pd.read_csv("nums_test.csv")
X_test, Y_test = df_test.values[:, 1:], df_test.values[:, 0]

# %%
Y_train = np_utils.to_categorical(Y_train)
Y_test = np_utils.to_categorical(Y_test)

# %%
model_sgd = Sequential()

model_sgd.add(Dense(output_dim = 10, activation = 'sigmoid'))
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=False)
model_sgd.compile(optimizer= sgd, loss='categorical_crossentropy', metrics=['accuracy'])
history_sgd = model_sgd.fit(X_train, Y_train, validation_data = (X_test, Y_test), epochs = 600);
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=10)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# Train on 10 samples, validate on 138 samples
# Epoch 1/600
# 10/10 [==============================] - 1s 86ms/step - loss: 2.4108 - acc: 0.0000e+00 - val_loss: 2.4269 - val_acc: 0.0652
# Epoch 2/600
# 10/10 [==============================] - 0s 800us/step - loss: 2.4098 - acc: 0.0000e+00 - val_loss: 2.4251 - val_acc: 0.0652
# Epoch 3/600
# 10/10 [==============================] - 0s 800us/step - loss: 2.4078 - acc: 0.0000e+00 - val_loss: 2.4225 - val_acc: 0.0652
# Epoch 4/600
# 10/10 [==============================] - 0s 799us/step - loss: 2.4050 - acc: 0.0000e+00 - val_loss: 2.4192 - val_acc: 0.0652
# Epoch 5/600
# 10/10 [==============================] - 0s 800us/step - loss: 2.4015 - acc: 0.0000e+00 - val_loss: 2.4153 - val_acc: 0.0652
# ...

# %%
model_sgd_nesterov = Sequential()

model_sgd_nesterov.add(Dense(output_dim = 10, activation = 'sigmoid'))
sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_sgd_nesterov.compile(optimizer= sgd, loss='categorical_crossentropy', metrics=['accuracy'])
history_sgd_nesterov = model_sgd_nesterov.fit(X_train, Y_train, validation_data = (X_test, Y_test), epochs = 600);
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=10)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# Train on 10 samples, validate on 138 samples
# Epoch 1/600
# 10/10 [==============================] - 1s 68ms/step - loss: 2.3301 - acc: 0.2000 - val_loss: 2.3315 - val_acc: 0.1884
# Epoch 2/600
# 10/10 [==============================] - 0s 1ms/step - loss: 2.3289 - acc: 0.2000 - val_loss: 2.3300 - val_acc: 0.1884
# Epoch 3/600
# 10/10 [==============================] - 0s 800us/step - loss: 2.3271 - acc: 0.2000 - val_loss: 2.3281 - val_acc: 0.1812
# Epoch 4/600
# 10/10 [==============================] - 0s 799us/step - loss: 2.3249 - acc: 0.2000 - val_loss: 2.3259 - val_acc: 0.1812
# Epoch 5/600
# 10/10 [==============================] - 0s 1ms/step - loss: 2.3222 - acc: 0.2000 - val_loss: 2.3234 - val_acc: 0.1812
# Epoch 6/600
# ...

# %%
model_adam = Sequential()

model_adam.add(Dense(output_dim = 10, activation = 'sigmoid'))
model_adam.compile(optimizer= 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
history_adam = model_adam.fit(X_train, Y_train, validation_data = (X_test, Y_test), epochs = 600);
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=10)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# Train on 10 samples, validate on 138 samples
# Epoch 1/600
# 10/10 [==============================] - 1s 93ms/step - loss: 2.3741 - acc: 0.1000 - val_loss: 2.3570 - val_acc: 0.0797
# Epoch 2/600
# 10/10 [==============================] - 0s 840us/step - loss: 2.3710 - acc: 0.1000 - val_loss: 2.3548 - val_acc: 0.0797
# Epoch 3/600
# 10/10 [==============================] - 0s 800us/step - loss: 2.3684 - acc: 0.1000 - val_loss: 2.3524 - val_acc: 0.0797
# Epoch 4/600
# 10/10 [==============================] - 0s 1ms/step - loss: 2.3656 - acc: 0.1000 - val_loss: 2.3500 - val_acc: 0.0797
# Epoch 5/600
# 10/10 [==============================] - 0s 1ms/step - loss: 2.3628 - acc: 0.1000 - val_loss: 2.3476 - val_acc: 0.0797
# Epoch 6/600
# ...

# %%
model_adagrad = Sequential()

model_adagrad.add(Dense(output_dim = 10, activation = 'sigmoid'))
model_adagrad.compile(optimizer= 'adagrad', loss='categorical_crossentropy', metrics=['accuracy'])
history_adagrad = model_adagrad.fit(X_train, Y_train, validation_data = (X_test, Y_test), epochs = 600);
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=10)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# Train on 10 samples, validate on 138 samples
# Epoch 1/600
# 10/10 [==============================] - 1s 62ms/step - loss: 2.5067 - acc: 0.0000e+00 - val_loss: 2.4424 - val_acc: 0.0217
# Epoch 2/600
# 10/10 [==============================] - 0s 800us/step - loss: 2.4781 - acc: 0.0000e+00 - val_loss: 2.4264 - val_acc: 0.0217
# Epoch 3/600
# 10/10 [==============================] - 0s 2ms/step - loss: 2.4591 - acc: 0.0000e+00 - val_loss: 2.4139 - val_acc: 0.0145
# Epoch 4/600
# 10/10 [==============================] - 0s 1ms/step - loss: 2.4442 - acc: 0.0000e+00 - val_loss: 2.4035 - val_acc: 0.0145
# Epoch 5/600
# 10/10 [==============================] - 0s 1ms/step - loss: 2.4318 - acc: 0.0000e+00 - val_loss: 2.3944 - val_acc: 0.0145
# Epoch 6/600
# ...

# %%
#model.predict(X_test[:4])

# %%
#y_test[:4]

# %%
plt.plot(history_sgd.history['acc'])
plt.plot(history_sgd_nesterov.history['acc'])
plt.plot(history_adam.history['acc'])
plt.plot(history_adagrad.history['acc'])
plt.title('Model train accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['SGD', 'SGD Nesterov', 'Adam', 'Adagrad'], loc='upper left')
plt.show()

plt.plot(history_sgd.history['val_acc'])
plt.plot(history_sgd_nesterov.history['val_acc'])
plt.plot(history_adam.history['val_acc'])
plt.plot(history_adagrad.history['val_acc'])
plt.title('Model test accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['SGD','SGD Nesterov','Adam', 'Adagrad'], loc='upper left')
plt.show()

plt.plot(history_sgd.history['loss'])
plt.plot(history_sgd_nesterov.history['loss'])
plt.plot(history_adam.history['loss'])
plt.plot(history_adagrad.history['loss'])
plt.title('Model train loss')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['SGD','SGD Nesterov', 'Adam', 'Adagrad'], loc='upper left')
plt.show()

plt.plot(history_sgd.history['val_loss'])
plt.plot(history_sgd_nesterov.history['val_loss'])
plt.plot(history_adam.history['val_loss'])
plt.plot(history_adagrad.history['val_loss'])
plt.title('Model test loss')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['SGD','SGD Nesterov', 'Adam', 'Adagrad'], loc='upper left')
plt.show()

# %%
#overfitting
model = Sequential()

model.add(Dense(output_dim=100, activation='sigmoid'))
model.add(Dense(output_dim=200, activation='sigmoid'))
model.add(Dense(output_dim=10, activation='sigmoid'))

sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer= sgd, loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, Y_train, validation_data = (X_test, Y_test), epochs = 600);
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=100)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=200)`
#   after removing the cwd from sys.path.
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=10)`
#   """
# Train on 10 samples, validate on 138 samples
# Epoch 1/600
# 10/10 [==============================] - 1s 118ms/step - loss: 2.3571 - acc: 0.1000 - val_loss: 2.3664 - val_acc: 0.0942
# Epoch 2/600
# 10/10 [==============================] - 0s 800us/step - loss: 2.3535 - acc: 0.1000 - val_loss: 2.3608 - val_acc: 0.0942
# Epoch 3/600
# ...

# %% [markdown]
# # Задание 2

# %%
def sequence(x):
    return 4*x*(1-x)

# %%
def generate_sequence(x0, n):
    x = [x0]
    for i in range(1, n):
        x.append(sequence(x[-1]))
    return x

# %%
S = generate_sequence(0.3, 1000000)

X = S[:-1]
Y = S[1:]

# %%
dims = [1, 5, 1]
v = 0.5

# %%
w_0 = np.ones(dims[1])
w = np.random.rand(dims[1])
b = np.ones(dims[1])

# %%
for t in range(0, 10000):
    x_0 = X[t]*w_0
    e = Y[t]
    
    z = np.abs(x_0-w)
    x = np.exp(-b*z**2)
    y = np.sum(x*w)

    for k in range(dims[1]):
        b[k] = b[k] + v*(y-e)*x[k]*w[k]*b[k]
        w[k] = w[k] - v*(y-e)*x[k]

# %%
w
# Out:
# array([ 0.3402485 ,  0.33057774, -1.4200887 ,  0.68435174,  0.23495338])

# %%
plt.figure()

for t in range(0, 100):
    x = X[t]*np.ones(dims[1])
    e = Y[t]
    
    z = np.abs(x-w)
    y = np.sum(np.exp(-b*z**2)*w)

    plt.plot(X[t], Y[t], 'bo')
    plt.plot(X[t], y, 'ro')

# %%
S = generate_sequence(0.3, 1000000)

X = S[:-1]
Y = S[1:]

# %%
dims = [1, 10, 1]
v = 0.1

# %%
w = np.random.rand(dims[1])
c = np.random.rand(dims[1])
b = np.ones(dims[1])

# %%
for t in range(0, 10000):
    x_0 = X[t]*np.ones(dims[1])
    e = Y[t]
    
    z = x_0-c
    x = np.exp(-b*z**2)
    y = np.sum(x*w)

    for k in range(dims[1]):
        b[k] = b[k] + v*(y-e)*x[k]*w[k]*b[k]
        w[k] = w[k] - v*(y-e)*x[k]
        c[k] = c[k] - v*(y-e)*x[k]*w[k]*2*np.sqrt(b[k]*np.log(1/x[k]))*(x[k]-c[k])/z[k]

# %%
plt.figure()

for t in range(0, 1000):
    x_0 = X[t]*np.ones(dims[1])
    e = Y[t]
    
    z = np.abs(x_0-c)
    x = np.exp(-b*z**2)
    y = np.sum(x*w)

    plt.plot(X[t], Y[t], 'bo')
    plt.plot(X[t], y, 'ro')
